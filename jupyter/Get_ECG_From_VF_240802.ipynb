# %%
import wfdb
import numpy as np
import os

# %%
# 데이터베이스와 VF 발생 시간 목록
databases = [
    ('30', '07:54:33'),
    ('31', '13:42:24'),
    ('32', '16:45:18'),
    ('33', '04:46:19'),
    ('34', '06:35:44'),
    ('35', '24:34:56'),
    ('36', '18:59:01'),
    ('37', '01:31:13'),
    ('38', '08:01:54'),
    ('39', '04:37:51'),
    #('40', None),  # pacing, no VF
    ('41', '02:59:24'),
    #('42', None),  # no VF
    ('43', '15:37:11'),
    ('44', '19:38:45'),
    ('45', '18:09:17'),
    ('46', '03:41:47'),
    ('47', '06:13:01'),
    ('48', '02:29:40'),
    #('49', None),  # pacing, no VF
    ('50', '11:45:43'),
    ('51', '22:58:23'),
    ('52', '02:32:40')
]

# %%
# 데이터 경로 및 저장 경로
data_path = '../data/sudden-cardiac-death-holter-database-1.0.0/'
save_path = '/smc_work/datanvme/VF/vf_before_min_60_120/'

# %%
# 설정 변수
start_interval = 120  # VF 발생 120분 전
end_interval = 60  # VF 발생 60분 전

# %%
db_number = '30'

# %%
record = wfdb.rdrecord(data_path + db_number)
annotation = wfdb.rdann(data_path + db_number,'atr')

# %%
plt.plot(record.p_signal[500:750])
plt.show()

# %%
record.sig_len
# Out:
# 22099250

# %%
record.fs
# Out:
# 250

# %%
len(annotation.symbol)
# Out:
# 128808

# %%
annotation.symbol
# Out:
# ['~',
#  '~',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'V',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  '|',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  '|',
#  'N',
#  '|',
#  '|',
#  'N',
#  'N',
#  'N',
#  'V',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
#  'N',
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(np.load('/smc_work/datanvme/VF/vf_before_min_60_120/30_VF_07-54-33_Segment_12_Start_25270-18_End_25270-60.npy'))
plt.show()
